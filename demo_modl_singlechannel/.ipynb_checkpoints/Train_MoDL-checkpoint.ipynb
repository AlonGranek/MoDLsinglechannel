# %% [markdown]
# # NPPC applied on MR image reconstruction

# %%
# %matplotlib notebook
import os, sys
import logging
import numpy as np
import torch
import torchvision
from utils import complex_utils as cplx
from utils.datasets import SliceData
from MoDL_single import UnrolledModel
from pathlib import Path

from datasets import Namespace, create_data_loaders
from modl_infrastructure import MoDLParams, MoDLWrapper
from alon.MoDLsinglechannel.demo_modl_singlechannel.subsample_fastmri import SaveableMask
from alon.config import *

from nppc_infrastructure import NPPCParams, NPPCForMoDLWrapper


logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# %load_ext autoreload
# %autoreload 0
# Out:
# /home/alon_granek/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ## Load modules

# %% [markdown]
# ### 1. Undersampling mask

# %%
# Load a mask
#   Ask for a UUID, else take the most recently-created one
mask_name = input('Enter mask name (if skipping, taking the most recently created): ')
if not mask_name.replace(' ', ''):
    latest_file = max(Path(MASKS_DIR).glob('*.pkl'), key=os.path.getctime)
    mask_name = latest_file.stem
    print(f'User skipped, thus loaded the latest mask {mask_name}')

mask = SaveableMask(masks_dir=MASKS_DIR)
mask.load(mask_name)
# Out:
# User skipped, thus loaded the latest mask Initial Poisson acc 6 calib (28 28)
# Successfully loaded mask generator from /home/alon_granek/PythonProjects/NPPC/alon/masks/Initial Poisson acc 6 calib (28 28).pkl

# %% [markdown]
# ### 2. MoDL

# %%
modl_params = MoDLParams()
modl_train_loader = create_data_loaders(modl_params, mask)
modl_checkpoint_dir = Path('/home/alon_granek/PythonProjects/NPPC/alon/checkpoints2')
modl_wrapper = MoDLWrapper(modl_params, modl_checkpoint_dir)
single_MoDL = modl_wrapper.load(modl_checkpoint_dir,
                                # model_name='Initial 4-step MoDL (2)', #'test',
                                model_name='MoDL 4-step regul 0.01',
                                epoch='last')
# Out:
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002452.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002467.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002469.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002512.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002629.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002641.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002876.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002888.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002914.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002940.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002941.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002960.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002964.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002993.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003008.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000508.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000531.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_203_6000942.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_209_6001397.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_210_6001914.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002033.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002229.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002305.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002340.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002392.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002668.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002673.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002683.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002696.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002703.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002720.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002724.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002750.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002774.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002817.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002862.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000269.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000302.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000322.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000488.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000535.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000588.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000628.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000657.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000727.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000749.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000760.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000774.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000776.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000814.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000861.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000867.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050026.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050055.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050059.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050102.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050159.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050255.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_6000162.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070034.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070099.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070133.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070143.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070179.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070214.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070241.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070251.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070404.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070490.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070505.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070612.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070742.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070786.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080127.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080154.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080208.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080240.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080257.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080493.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080576.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080626.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080637.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080664.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080704.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001199.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001236.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001250.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001434.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001672.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001790.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001850.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002047.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002128.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002247.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002304.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002309.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002408.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_201_6002849.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000672.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000685.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000707.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000795.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000821.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000837.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000860.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_205_6000093.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000196.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000217.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000251.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_209_6001122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001656.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001891.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001893.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002717.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002836.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020098.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020109.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020146.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020186.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020209.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020377.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020384.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020389.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020478.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020496.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020509.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020570.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000305.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000312.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000339.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000347.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000534.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_206_6000204.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000020.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000175.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000360.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000362.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000407.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000488.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000566.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000592.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000600.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000621.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001980.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002012.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002100.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002111.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002151.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002158.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002228.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002262.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002302.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002308.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002375.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002381.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002387.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002446.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002465.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002528.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002530.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002545.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002551.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002594.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002601.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002655.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010014.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010029.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010132.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010156.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010168.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010174.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010177.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010239.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010241.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010323.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010332.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010338.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010348.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010398.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010416.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010455.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010571.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010588.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010602.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010625.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010626.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010628.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_6002681.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020016.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020039.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020065.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020067.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020127.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020183.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020214.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020272.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020273.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020297.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020331.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020358.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020409.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020489.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020555.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030096.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030135.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030254.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030256.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030288.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040009.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040011.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040042.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040073.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050062.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050130.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050244.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000091.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060013.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060027.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060029.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060070.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060079.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070039.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070054.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070100.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070145.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070165.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070194.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070198.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070208.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070249.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070280.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070325.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070417.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070422.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070458.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070460.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070562.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070581.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070608.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070690.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070692.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070703.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070709.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070770.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070777.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070822.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070834.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080013.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080050.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080051.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080091.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080126.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080186.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080192.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080228.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080277.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080303.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080329.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080333.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080354.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080445.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080475.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080526.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080591.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080611.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080630.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080635.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080713.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080722.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090151.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090215.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090266.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090333.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090339.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090406.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6000981.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001025.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001248.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001317.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001328.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001384.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001420.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001425.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001432.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001436.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001459.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001463.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100083.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100105.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100136.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100260.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100276.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100306.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100311.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100343.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100345.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100368.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001491.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001506.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001515.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001518.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001534.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001546.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001583.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001617.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001651.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001677.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001694.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001709.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001711.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001747.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001763.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001833.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001909.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001928.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001941.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001944.h5.npy...
# shared weights
# search_str:  Model MoDL 4-step regul 0.01  epoch *

# %% [markdown]
# **Optional test run of MoDL**

# %%
modl_wrapper.test_run(single_MoDL, modl_train_loader)
# Out:
# iter=15...
# 		Step 0/4...
# 		Step 1/4...
# 		Step 2/4...
# 		Step 3/4...
# <div id='2d403d09-f17d-423d-8dee-ae4fe4de63f5'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 modl_wrapper.test_run(single_MoDL, modl_train_loader)
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/modl_infrastructure.py:192, in MoDLWrapper.test_run(self, modl, data_loader, show_steps)
#     189     plt.tight_layout()
#     190     fig.show()
# --> 192 action = int(input('0 - Save   |    1 - Continue   |   2 - Exit'))
#     193 if action == 0:
#     194     save_name = str(input('Name:'))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### 3. NPPC

# %%
nppc_params = NPPCParams()
nppc_checkpoint_dir = Path('/home/alon_granek/PythonProjects/NPPC/alon/nppc_checkpoints')
nppc_wrapper = NPPCForMoDLWrapper(nppc_params, single_MoDL, save_dir=nppc_checkpoint_dir)

nppc_name: str = {
    # No DC loss, original NPPC edited for dual-channel data
    '1.0': 'modl_nppc_dc DUAL NO-DC fixed',
    
    # With DC loss                                              (July meeting)
    '1.1': 'modl_nppc_dc DUAL DC',
    
    # DC as an activation
    '2.0': 'modl_nppc_dc DUAL MaskAct 10dirs',
    
    # DC as an activation - but prior to Gram Schmidt
    '2.1': 'modl_nppc_dc DUAL MaskActPreGS',
    
    # Alternate between GS and DC Activation                    (Current as of August)
    '2.2': 'modl_nppc_dc DUAL AlterProj',
}[
    # --- Chosen ---
    '2.2'
]

nppc_net = nppc_wrapper.load(nppc_name)

# %% [markdown]
# ## Run on a file

# %%
for iter, data in enumerate(modl_train_loader):
    # Unpack data: undersampled k-space, target image, k-space mask
    y, x_true, mask_tensor = (obj.to(device) for obj in data)
    break

# """ Or use a temporarily saved file """
# import pickle
# with open('/home/alon_granek/PythonProjects/NPPC/temp_data.pkl', 'rb') as file:
#     y, x_true, mask = pickle.load(file)

# %%
preproc = lambda x, pos: x[pos].permute(0, 3, 1, 2)

with torch.no_grad():
    x_recon, x_intermed = single_MoDL(y.float(), mask=mask_tensor, return_steps=True)
    w_mat_intermed = nppc_net(preproc(x_intermed, 0), preproc(x_intermed, -1), mask_tensor)
# Out:
# 		Step 0/4...
# 		Step 1/4...
# 		Step 2/4...
# 		Step 3/4...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### _k-space error distribution_

# %%
import matplotlib.pyplot as plt
from alon.fastmri_preprocess import fftc
from alon.MoDLsinglechannel.demo_modl_singlechannel.utils.transforms import fft2, ifft2

example = 0

fig, ax = plt.subplots(1, 3, sharex=True, sharey=True)
# ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower')
im = ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)
ax[1].imshow(10 * np.log10(cplx.abs(ifft2(x_recon[example]))), cmap='inferno', origin='lower', vmin=-30)
ax[2].imshow(10 * np.log10(cplx.abs(ifft2(x_recon[example] - x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)
             
             # Adjusting the figure size and layout
fig.set_size_inches(20, 5)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)
# Out:
# <div id='bab8dd7a-60de-4fbf-aca9-cb4971af2c95'></div>
# /tmp/ipykernel_242569/3218010342.py:9: RuntimeWarning: divide by zero encountered in log10
#   im = ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)

# %% [markdown]
# ### _PCs_

# %%
import matplotlib.pyplot as plt
from alon.fastmri_preprocess import fftc
# plt.style.use('dark_background')
sample = 1

# Showing all PCs
fig, ax = plt.subplots(3, 5, sharex=True, sharey=True)
for c in range(5):
    eigval = (torch.linalg.norm(w_mat_intermed.detach()[sample, c, 0]) + torch.linalg.norm(w_mat_intermed.detach()[sample, c, 1])) / torch.prod(torch.tensor(w_mat_intermed.detach()[sample, c, 0].size()))
    ax[0, c].set_title('Eig. val.: {:e}'.format(eigval))
    for re_im in [0, 1]:
        # im = ax[re_im, c].imshow(w_mat_intermed.detach()[sample, c, re_im] / abs(w_mat_intermed.detach()[sample, c, re_im]).max(), vmin=-0.3, vmax=0.3, cmap='RdBu', origin='lower')
        im = ax[re_im, c].imshow(w_mat_intermed.detach()[sample, c, re_im], vmin=-0.3, vmax=0.3, cmap='RdBu', origin='lower')

    # # Showing spectra instead
    image = w_mat_intermed.detach()[sample, c].permute(1, 2, 0)[None]
    ax[2, c].imshow(10 * np.log10(np.maximum(cplx.abs(fft2(image))[0], 1e-4)), cmap='inferno', origin='lower')
    
    # im = ax[c].imshow(10 * np.log10(abs(fftc(image))), cmap='inferno', origin='lower')
    # im = ax[c].imshow(np.sign(fftc(image).real) * 10 * np.log10(abs(fftc(image))), origin='lower', cmap='RdBu')
    #im = ax[c].imshow(fftc(image).real, origin='lower', cmap='RdBu', vmin=-0.05, vmax=0.05)

# Adjusting the figure size and layout
fig.set_size_inches(30, 15)
# fig.subplots_adjust(right=0.8, wspace=0.05)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)

# Showing the figure
plt.show()

# fig.savefig('/home/alon_granek/PythonProjects/NPPC/temp4 (5).png')
# fig.show()
# Out:
# <div id='6b9a011c-be35-49cc-bf8c-5a4fc2b83528'></div>

# %% [markdown]
# ### _Relative k-space power distribution of PCs_

# %%
sample = 0
fts = torch.tensor([abs(fftc(w_mat_intermed.detach()[sample, c, 0])) for c in range(5)])
# normed = w_mat_intermed.detach()[sample, :, 0] / w_mat_intermed.detach()[sample, :, 0].sum(axis=0, keepdims=True)
normed = fts / fts.sum(dim=0, keepdims=True)

from scipy.ndimage import median_filter

fig, ax = plt.subplots(1, 5, sharex=True, sharey=True)
for c in range(5):
    ax[c].set_title(f'PC {c + 1}')
    im = ax[c].imshow(median_filter(10 * np.log10(normed[c]), [8, 8]), cmap='plasma', origin='lower', vmin=-9)
    
# Adjusting the figure size and layout
fig.set_size_inches(20, 5)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)

# Showing the figure
plt.show()
# fig.savefig('/home/alon_granek/PythonProjects/NPPC/kspace pcs DC.png')

# %% [markdown]
# ...

# %%
""" IN THAT ATTEMPT - TEST MODEL """
# Show how they behave on a given file
#nppc_net = nppc_wrapper.load(f'modl_nppc_dc END-TO-END NO-DC (faster)')
# nppc_net = nppc_wrapper.load(f'modl_nppc_dc END-TO-END DC test')#(l 8)')
# preproc = lambda x, pos: cplx.abs(x[pos])[:, None, ...]
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL NO-DC fixed')
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL DC')
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL DC20 NullErr')

# DC as an activation
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL MaskAct 10dirs')

# DC as an activation - but prior to Gram Schmidt
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL MaskActPreGS')

# Alternate between GS and Fourier Activation
nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL AlterProj')






""" Load new samples """
for iter, data in enumerate(modl_train_loader):
    # Unpack training data: subsampled k-space, target image, k-space mask
    y, x_true, mask = (obj.to(device) for obj in data)
    break
# """ Or use temporarily saved ones """
# import pickle
# with open('/home/alon_granek/PythonProjects/NPPC/temp_data.pkl', 'rb') as file:
#     y, x_true, mask = pickle.load(file)
# 

# Reconstruct, apply NPPC, calculate image-domain error
# from nppc_infrastructure import fourier_activation

preproc = lambda x, pos: x[pos].permute(0, 3, 1, 2) #[:, None, ...]

with torch.no_grad():
    x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
    w_mat_intermed = nppc_net(preproc(x_intermed, 0), preproc(x_intermed, -1), mask)
    # w_mat_intermed = fourier_activation(w_mat_intermed, mask)

# %% [markdown]
# # Data preparation

# %% [markdown]
# ### 1. Mask

# %%
from datasets import Namespace, create_data_loaders

# %% [markdown]
# ### 2. MoDL setup

# %%
from modl_infrastructure import MoDLParams, MoDLWrapper
from alon.MoDLsinglechannel.demo_modl_singlechannel.subsample_fastmri import SaveableMask
from alon.config import *

# Load a mask
#   Ask for a UUID, else take the most recently-created one
mask_name = input('Enter mask name (if skipping, taking the most recently created): ')
if not mask_name.replace(' ', ''):
    latest_file = max(Path(MASKS_DIR).glob('*.pkl'), key=os.path.getctime)
    mask_name = latest_file.stem
    print(f'User skipped, thus loaded the latest mask {mask_name}')

mask = SaveableMask(masks_dir=MASKS_DIR)
mask.load(mask_name)


modl_params = MoDLParams()
modl_train_loader = create_data_loaders(modl_params, mask)
modl_checkpoint_dir = Path('/home/alon_granek/PythonProjects/NPPC/alon/checkpoints2')
modl_wrapper = MoDLWrapper(modl_params, modl_checkpoint_dir)
# Out:
# User skipped, thus loaded the latest mask Initial Poisson acc 6 calib (28 28)
# Successfully loaded mask generator from /home/alon_granek/PythonProjects/NPPC/alon/masks/Initial Poisson acc 6 calib (28 28).pkl
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002452.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002467.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002469.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002512.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002629.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002641.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002876.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002888.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002914.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002940.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002941.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002960.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002964.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6002993.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003008.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000508.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000531.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_203_6000942.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_209_6001397.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_210_6001914.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002033.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002229.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002305.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002340.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002392.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002668.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002673.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002683.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002696.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002703.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002720.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002724.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002750.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002774.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002817.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002862.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000269.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000302.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000322.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000488.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000535.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000588.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000628.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000657.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000727.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000749.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000760.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000774.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000776.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000814.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000861.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000867.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050026.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050055.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050059.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050102.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050159.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050255.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_6000162.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070034.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070099.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070133.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070143.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070179.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070214.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070241.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070251.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070404.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070490.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070505.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070612.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070742.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070786.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080127.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080154.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080208.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080240.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080257.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080493.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080576.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080626.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080637.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080664.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080704.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001199.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001236.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001250.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001434.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001672.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001790.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_210_6001850.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002047.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002128.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002247.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002304.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002309.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002408.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_201_6002849.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000672.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000685.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000707.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000795.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000821.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000837.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000860.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_205_6000093.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000196.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000217.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000251.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_209_6001122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001656.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001891.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001893.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002717.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002836.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020098.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020109.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020146.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020186.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020209.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020377.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020384.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020389.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020478.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020496.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020509.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020570.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000305.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000312.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000339.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000347.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000534.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_206_6000204.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000020.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000175.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000360.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000362.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000407.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000488.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000566.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000592.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000600.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000621.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001980.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002012.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002100.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002111.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002151.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002158.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002228.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002262.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002302.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002308.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002375.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002381.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002387.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002446.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002465.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002486.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002528.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002530.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002545.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002551.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002594.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002601.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002655.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010014.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010029.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010132.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010156.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010168.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010174.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010177.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010239.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010241.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010323.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010332.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010338.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010348.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010398.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010416.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010455.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010532.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010571.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010588.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010602.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010625.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010626.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010628.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_6002681.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020016.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020039.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020065.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020067.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020127.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020183.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020214.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020272.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020273.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020297.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020331.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020358.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020409.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020489.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020555.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030096.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030135.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030254.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030256.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030288.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040009.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040011.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040042.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040073.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050062.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050130.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050244.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000091.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060003.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060013.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060027.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060029.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060070.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060079.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070039.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070054.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070100.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070145.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070165.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070194.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070198.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070208.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070249.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070280.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070325.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070352.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070417.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070422.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070458.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070460.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070500.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070562.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070581.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070608.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070690.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070692.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070703.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070709.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070770.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070777.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070822.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070834.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080013.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080050.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080051.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080091.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080126.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080186.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080192.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080228.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080277.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080303.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080329.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080333.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080354.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080445.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080475.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080526.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080591.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080611.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080630.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080635.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080713.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080722.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090151.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090215.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090266.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090333.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090339.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090406.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6000981.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001025.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001248.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001317.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001328.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001384.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001420.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001425.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001432.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001436.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001459.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001463.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100083.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100105.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100136.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100260.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100276.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100306.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100311.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100343.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100345.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100368.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001491.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001506.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001515.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001518.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001534.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001546.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001583.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001617.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001651.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001677.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001694.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001709.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001711.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001737.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001747.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001763.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001833.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001909.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001928.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001941.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001944.h5.npy...
# shared weights

# %% [markdown]
# ### 3. Train MoDL, or load a MoDL model

# %%
""" Loading """
single_MoDL = modl_wrapper.load(modl_checkpoint_dir,
                                # model_name='Initial 4-step MoDL (2)', #'test',
                                model_name='MoDL 4-step regul 0.01',
                                epoch='last')
# Out:
# search_str:  Model MoDL 4-step regul 0.01  epoch *

# %%
""" MoDL test run """
modl_wrapper.test_run(single_MoDL, modl_train_loader)
# Out:
# iter=355...
# 		Step 0/4...
# 		Step 1/4...
# 		Step 2/4...
# 		Step 3/4...
# <div id='e6c7d6bf-e95c-40e9-82de-5b3d703ce208'></div>
# Saved figure in: /home/alon_granek/PythonProjects/NPPC/alon/MoDLsinglechannel/temp1.png
# <div id='af402bed-de45-4bf5-8a5b-adba12aa6338'></div>
# Saved figure in: /home/alon_granek/PythonProjects/NPPC/alon/MoDLsinglechannel/temp2.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 """ MoDL test run """
# ----> 2 modl_wrapper.test_run(single_MoDL, modl_train_loader)
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/modl_infrastructure.py:160, in MoDLWrapper.test_run(self, modl, data_loader, show_steps)
#     157 in_image = torch.tensor(abs(ifftc(torch.tensor(fftc(gt_image)) * mask[..., 0]))).to(self.device)  # abs(ifftc(in_kspace[..., 0]) + 1j * ifftc(in_kspace[..., 1]))
#     159 while True:
# --> 160     sample = int(input(
#     161         f'Which sample (in range [0, {gt_image.shape[0] - 1}]) would you like to display?'
#     162         f'Insert -1 to exit'
#     163     ))
#     164     if sample == -1:
#     165         return
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from nppc_infrastructure import NPPCParams, NPPCForMoDLWrapper

nppc_params = NPPCParams()
nppc_checkpoint_dir = Path('/home/alon_granek/PythonProjects/NPPC/alon/nppc_checkpoints')
nppc_wrapper = NPPCForMoDLWrapper(nppc_params, single_MoDL, save_dir=nppc_checkpoint_dir)

# %%
""" IN THAT ATTEMPT - TEST MODEL """
# Show how they behave on a given file
#nppc_net = nppc_wrapper.load(f'modl_nppc_dc END-TO-END NO-DC (faster)')
# nppc_net = nppc_wrapper.load(f'modl_nppc_dc END-TO-END DC test')#(l 8)')
# preproc = lambda x, pos: cplx.abs(x[pos])[:, None, ...]
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL NO-DC fixed')
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL DC')
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL DC20 NullErr')

# DC as an activation
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL MaskAct 10dirs')

# DC as an activation - but prior to Gram Schmidt
# nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL MaskActPreGS')

# Alternate between GS and Fourier Activation
nppc_net = nppc_wrapper.load('modl_nppc_dc DUAL AlterProj')
preproc = lambda x, pos: x[pos].permute(0, 3, 1, 2) #[:, None, ...]


""" Load new samples """
for iter, data in enumerate(modl_train_loader):
    # Unpack training data: subsampled k-space, target image, k-space mask
    y, x_true, mask = (obj.to(device) for obj in data)
    break
# """ Or use temporarily saved ones """
# import pickle
# with open('/home/alon_granek/PythonProjects/NPPC/temp_data.pkl', 'rb') as file:
#     y, x_true, mask = pickle.load(file)
# 

# Reconstruct, apply NPPC, calculate image-domain error
# from nppc_infrastructure import fourier_activation

with torch.no_grad():
    x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
    w_mat_intermed = nppc_net(preproc(x_intermed, 0), preproc(x_intermed, -1), mask)
    # w_mat_intermed = fourier_activation(w_mat_intermed, mask)
# Out:
# 		Step 0/4...
# 		Step 1/4...
# 		Step 2/4...
# 		Step 3/4...

# %%
import pickle

save_path = '/home/alon_granek/PythonProjects/NPPC/temp_data.pkl'
with open(save_path, 'wb') as file:
    pickle.dump(data, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 save_path = '/home/alon_granek/PythonProjects/NPPC/temp_data.pkl'
#       4 with open(save_path, 'wb') as file:
# ----> 5     pickle.dump(data, file)
#
# NameError: name 'data' is not defined

# %%
import matplotlib.pyplot as plt
from alon.fastmri_preprocess import fftc
from alon.MoDLsinglechannel.demo_modl_singlechannel.utils.transforms import fft2, ifft2

example = 0

fig, ax = plt.subplots(1, 3, sharex=True, sharey=True)
# ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower')
im = ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)
ax[1].imshow(10 * np.log10(cplx.abs(ifft2(x_recon[example]))), cmap='inferno', origin='lower', vmin=-30)
ax[2].imshow(10 * np.log10(cplx.abs(ifft2(x_recon[example] - x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)
             
             # Adjusting the figure size and layout
fig.set_size_inches(20, 5)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)
# Out:
# <div id='e6369849-2489-4692-8654-ef6c5bec3076'></div>
# /tmp/ipykernel_233506/3218010342.py:9: RuntimeWarning: divide by zero encountered in log10
#   im = ax[0].imshow(10 * np.log10(cplx.abs(fft2(x_intermed[0][example]))), cmap='inferno', origin='lower', vmin=-30)

# %%
cplx.abs(fft2(x_intermed[example])).shape
# Out:
# torch.Size([2, 372, 372])

# %%
sample = 0
fts = torch.tensor([abs(fftc(w_mat_intermed.detach()[sample, c, 0])) for c in range(5)])
# normed = w_mat_intermed.detach()[sample, :, 0] / w_mat_intermed.detach()[sample, :, 0].sum(axis=0, keepdims=True)
normed = fts / fts.sum(dim=0, keepdims=True)

from scipy.ndimage import median_filter

fig, ax = plt.subplots(1, 5, sharex=True, sharey=True)
for c in range(5):
    ax[c].set_title(f'PC {c + 1}')
    im = ax[c].imshow(median_filter(10 * np.log10(normed[c]), [8, 8]), cmap='plasma', origin='lower', vmin=-9)
    
# Adjusting the figure size and layout
fig.set_size_inches(20, 5)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)

# Showing the figure
plt.show()
# fig.savefig('/home/alon_granek/PythonProjects/NPPC/kspace pcs DC.png')
# Out:
# /tmp/ipykernel_233506/3070644637.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   fts = torch.tensor([abs(fftc(w_mat_intermed.detach()[sample, c, 0])) for c in range(5)])
# <div id='75587db6-e166-4803-8e0a-0abca4e287d1'></div>

# %%
import matplotlib.pyplot as plt
from alon.fastmri_preprocess import fftc
# plt.style.use('dark_background')
sample = 1

# Showing all PCs
fig, ax = plt.subplots(3, 5, sharex=True, sharey=True)
for c in range(5):
    eigval = (torch.linalg.norm(w_mat_intermed.detach()[sample, c, 0]) + torch.linalg.norm(w_mat_intermed.detach()[sample, c, 1])) / torch.prod(torch.tensor(w_mat_intermed.detach()[sample, c, 0].size()))
    ax[0, c].set_title('Eig. val.: {:e}'.format(eigval))
    for re_im in [0, 1]:
        # im = ax[re_im, c].imshow(w_mat_intermed.detach()[sample, c, re_im] / abs(w_mat_intermed.detach()[sample, c, re_im]).max(), vmin=-0.3, vmax=0.3, cmap='RdBu', origin='lower')
        im = ax[re_im, c].imshow(w_mat_intermed.detach()[sample, c, re_im], vmin=-0.3, vmax=0.3, cmap='RdBu', origin='lower')

    # # Showing spectra instead
    image = w_mat_intermed.detach()[sample, c].permute(1, 2, 0)[None]
    ax[2, c].imshow(10 * np.log10(np.maximum(cplx.abs(fft2(image))[0], 1e-4)), cmap='inferno', origin='lower')
    
    # im = ax[c].imshow(10 * np.log10(abs(fftc(image))), cmap='inferno', origin='lower')
    # im = ax[c].imshow(np.sign(fftc(image).real) * 10 * np.log10(abs(fftc(image))), origin='lower', cmap='RdBu')
    #im = ax[c].imshow(fftc(image).real, origin='lower', cmap='RdBu', vmin=-0.05, vmax=0.05)

# Adjusting the figure size and layout
fig.set_size_inches(30, 15)
# fig.subplots_adjust(right=0.8, wspace=0.05)
fig.subplots_adjust(right=0.8, wspace=0.05)

# Adding a separate axis for the colorbar
cbar_ax = fig.add_axes([0.83, 0.3, 0.015, 0.4])
fig.colorbar(mappable=im, cax=cbar_ax)

# Showing the figure
plt.show()

# fig.savefig('/home/alon_granek/PythonProjects/NPPC/temp4 (5).png')
# fig.show()
# Out:
# <div id='a32b022a-0290-4350-95a3-e5903af53939'></div>

# %%
def fourier_activation(w_mat: torch.Tensor, mask: torch.Tensor):
    """
    Activation of sampling mask

    :param w_mat:
    :param mask:
    :return:
    """
    w_mat_ksp = fft2(w_mat.permute(0, 3, 4, 1, 2))
    w_mat_ksp_filt = (1 - mask[0, :, :, 0][None, :, :, None, None]) * w_mat_ksp
    w_mat_filt = ifft2(w_mat_ksp_filt).permute(0, 3, 4, 1, 2)
    # 'cije, eijkc'
    return w_mat_filt

# %%
from nppc.nppc import gram_schmidt

w_mat = torch.clone(w_mat_intermed)
for i in range(5):
    w_mat = gram_schmidt(fourier_activation(w_mat, mask))

# %%
u = w_mat_intermed.detach()[sample, 0, 0] / abs(w_mat_intermed.detach()[sample, 0, 0]).max()
v = w_mat_intermed.detach()[sample, 1, 0] / abs(w_mat_intermed.detach()[sample, 1, 0]).max()

# %%
u.flatten().dot(v.flatten()) / u.flatten().dot(u.flatten())
# Out:
# tensor(0.9844)

# %%
plt.figure()
plt.imshow(10 * np.log10(abs(fftc(torch.linalg.norm(w_mat_intermed.detach()[sample, :, 0], axis=0)))))
# Out:
# <div id='60d99ea6-8bec-4d41-9c10-d6a10938cf75'></div>

# %%
fig, ax = plt.subplots(1, 2 + len(x_intermed), sharex=True, sharey=True)
ax[0].set_title('Target')
ax[0].imshow(torch.flipud(cplx.abs(x_true)[sample]), cmap='Greys_r', vmin=0, vmax=1.2)
ax[1].set_title('6x accelerated zero-filled')
ax[1].imshow(torch.flipud(cplx.abs(x_intermed[0])[sample].detach()), cmap='Greys_r', vmin=0, vmax=1.2)
for i in range(2, 2 + len(x_intermed)):
    ax[i].set_title(f'Recon step {i - 2}')
    ax[i].imshow(torch.flipud(cplx.abs(x_intermed[i - 2][sample].detach())), cmap='Greys_r', vmin=0,
                 vmax=1.2)
fig.set_size_inches(30, 7)
plt.tight_layout()
fig.savefig('/home/alon_granek/PythonProjects/NPPC/modl.png')
fig.show()
# Out:
# <div id='8aa3727f-a5ce-4494-8313-1f71cd66699a'></div>

# %%
for pos in range(single_MoDL.num_grad_steps - 1):
    print(f'TRAINING ON MODL POSITION {pos}')
    # if pos in [0, 1]:
    #     continue
    #todo Train for [6, 7]
    nppc_wrapper.train(modl_train_loader, nppc_position=pos, model_name=f'modl_nppc_dc pos {pos}')
    nppc_wrapper.reset()
# Out:
# TRAINING ON MODL POSITION 0
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 7.190761089324951
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 5.231410980224609
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.487597942352295
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.347703456878662
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.398761510848999
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.683410167694092
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.640946865081787
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.8622565269470215
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.59844970703125
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.6916661262512207
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.109078884124756
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.125545024871826
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.173495292663574
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.10699725151062
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.9536739587783813
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 32...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 33...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.8229432106018066
# TRAINING ON MODL POSITION 1
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 7.220503330230713
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.5424089431762695
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.3239402770996094
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.981691837310791
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.686201572418213
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.563094139099121
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.162356376647949
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.232285499572754
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.247736930847168
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.981101393699646
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.79600191116333
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.8350756168365479
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.8333903551101685
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.9308531284332275
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.6513110399246216
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 32...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 33...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.544745683670044
# TRAINING ON MODL POSITION 2
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 7.489079475402832
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.305383682250977
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.4380111694335938
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.608280658721924
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.5402889251708984
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.4571399688720703
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.1321921348571777
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.8600757122039795
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.9438167810440063
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.8273296356201172
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.6122581958770752
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.5571906566619873
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.6425447463989258
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.6598312854766846
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.6046442985534668
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 32...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 33...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.5560472011566162
# TRAINING ON MODL POSITION 3
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 7.650889873504639
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.8034257888793945
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.543344020843506
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.225837230682373
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.0657570362091064
# Iter 10...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 11...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.9441866874694824
# Iter 12...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 13...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.9669148921966553
# Iter 14...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 15...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.548085927963257
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.3362913131713867
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.0728867053985596
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.1265549659729004
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.1573097705841064
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.085848331451416
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.9539562463760376
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.987884521484375
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 32...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 33...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.909486174583435
# TRAINING ON MODL POSITION 4
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 6.701255798339844
# Iter 2...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 3...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 4.995928764343262
# Iter 4...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 5...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.81154465675354
# Iter 6...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 7...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 9...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.119987964630127
# Iter 8...
# 		Step 0/8...
# 		Step 1/8...
# ...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.186566114425659
# Iter 16...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 17...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 3.146286725997925
# Iter 18...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 19...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.7720508575439453
# Iter 20...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 21...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.4209794998168945
# Iter 22...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 23...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.2614572048187256
# Iter 24...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 25...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.201456069946289
# Iter 26...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 27...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.1818461418151855
# Iter 28...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 29...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 2.2408266067504883
# Iter 30...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 31...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 32...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 33...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Loss: 1.9932421445846558
# TRAINING ON MODL POSITION 6
# Iter 0...
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...
# 	Reconstructed
# 	Estimated principal components
# Iter 1...
# 		Step 0/8...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 print(f'TRAINING ON MODL POSITION {pos}')
#       3 # if pos in [0, 1]:
#       4 #     continue
# ----> 5 nppc_wrapper.train(modl_train_loader, nppc_position=pos, model_name=f'modl_nppc_dc pos {pos}')
#       6 nppc_wrapper.reset()
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/nppc_infrastructure.py:164, in NPPCForMoDLWrapper.train(self, data_loader, nppc_position, model_name, save_freq)
#     162 def train(self, data_loader: DataLoader, nppc_position, model_name: str = 'modl_nppc_dc', save_freq: int = 1):
#     163     for loss_calc_batch in range(self.nppc_params.max_loss_calc_batches):
# --> 164         objective = self._accumulate_losses(data_loader, nppc_position, loss_calc_batch)
#     165         self.nppc_optimizer.zero_grad()
#     166         objective.backward()
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/nppc_infrastructure.py:179, in NPPCForMoDLWrapper._accumulate_losses(self, data_loader, nppc_position, loss_calc_batch)
#     177 for iter, data in enumerate(data_loader, start=start):
#     178     print(f'Iter {iter}...')
# --> 179     losses.append(self._get_batch_loss(data, nppc_position))
#     180     if len(losses) == self.nppc_params.batches_per_loss_calc:
#     181         break
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/nppc_infrastructure.py:201, in NPPCForMoDLWrapper._get_batch_loss(self, data, nppc_position)
#     199 # Reconstruct, apply NPPC, calculate image-domain error
#     200 with torch.no_grad():
# --> 201     x_recon, x_intermed = self.modl(y.float(), mask=mask, return_steps=True)
#     202 print('\tReconstructed')
#     204 step_input = cplx.abs(x_intermed[nppc_position])[:, None, ...]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/MoDL_single.py:108, in UnrolledModel.forward(self, kspace, init_image, mask, return_steps)
#     106             image = image.permute(0,3,1,2)
#     107 #             pl.ImagePlot(image.detach().cpu())
# --> 108             image = resnet(image)
#     109             image = image.permute(0,2,3,1)
#     110             rhs = zf_image + self.modl_lamda * image
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_model.py:32, in UNet.forward(self, x)
#      31 def forward(self, x):
# ---> 32     x1 = self.inc(x)
#      33     x2 = self.down1(x1)
#      34     x3 = self.down2(x2)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_parts.py:32, in inconv.forward(self, x)
#      31 def forward(self, x):
# ---> 32     x = self.conv(x)
#      33     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_parts.py:22, in double_conv.forward(self, x)
#      21 def forward(self, x):
# ---> 22     x = self.conv(x)
#      23     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:175, in _BatchNorm.forward(self, input)
#     168     bn_training = (self.running_mean is None) and (self.running_var is None)
#     170 r"""
#     171 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     172 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     173 used for normalization (i.e. in eval mode when buffers are not None).
#     174 """
# --> 175 return F.batch_norm(
#     176     input,
#     177     # If buffers are not to be tracked, ensure that they won't be updated
#     178     self.running_mean
#     179     if not self.training or self.track_running_stats
#     180     else None,
#     181     self.running_var if not self.training or self.track_running_stats else None,
#     182     self.weight,
#     183     self.bias,
#     184     bn_training,
#     185     exponential_average_factor,
#     186     self.eps,
#     187 )
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:2509, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2506 if training:
#    2507     _verify_batch_size(input.size())
# -> 2509 return torch.batch_norm(
#    2510     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2511 )
#
# KeyboardInterrupt:

# %%
""" Load models of different steps """
# Show how they behave on a given file
nppc_nets = [nppc_wrapper.load(f'modl_nppc_dc pos {pos}') for pos in range(6)]#single_MoDL.num_grad_steps - 1)]
input_positions = np.arange(0, 6) #single_MoDL.num_grad_steps - 1)
mmse_positions = input_positions + 1
preproc = lambda x, pos: cplx.abs(x[pos])[:, None, ...]

for iter, data in enumerate(modl_train_loader):
    # Unpack training data: subsampled k-space, target image, k-space mask
    y, x_true, mask = (obj.to(device) for obj in data)
    break

# Reconstruct, apply NPPC, calculate image-domain error
with torch.no_grad():
    x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
    w_mat_intermed = [nppc_nets[i](preproc(x_intermed, i), preproc(x_intermed, j)) for i, j in zip(input_positions, mmse_positions)]
# Out:
# 		Step 0/8...
# 		Step 1/8...
# 		Step 2/8...
# 		Step 3/8...
# 		Step 4/8...
# 		Step 5/8...
# 		Step 6/8...
# 		Step 7/8...

# %%
""" Display the PCs """
import matplotlib.pyplot as plt

sample = 0

# Showing all PCs
fig, ax = plt.subplots(2, 5, sharex=True, sharey=True)
for pos in [0, 1]:
    for c in range(5):
        ax[pos, c].set_title(f'PC {c + 1}')
        ax[pos, c].imshow(w_mat_intermed[pos].detach()[sample, c, 0], vmin=-0.5, vmax=0.5, cmap='RdBu')
# fig.set_size_inches(20, 6)
fig.set_size_inches(20, 10)
fig.tight_layout()
# fig.savefig('/home/alon_granek/PythonProjects/NPPC/temp2.png')
fig.show()
# Out:
# <div id='8d5e1d06-0baf-409a-9d24-75569f994557'></div>

# %%
""" Branch new examples from the existing PC subspace """

# %%
""" Insane ideas to combine them - PCA on the smallest required point cloud """

points = w_mat_intermed[0]

# %%
""" Reconstruct covariance """

# W D W
# D is the eigenvectors
example = 0
w_mat = w_mat_intermed[example]

w_mat_ = w_mat.flatten(3)
w_norms = w_mat_.norm(dim=3)
w_hat_mat = w_mat_ / w_norms[:, :, None]

# D = torch.diag(w_norms[:, 0])
# W = w_hat_mat[:, 0]
# DW = torch.einsum('ck, ki -> ci', D, W)
# WDW = torch.einsum('ci, cj -> ij', W, DW)

# %%
w_mat.shape
# Out:
# torch.Size([2, 5, 1, 372, 372])

# %%
#todo Turn this into a differentiable PCWalk object. PC vectors' positions in the shared basis are pre-determined, the function merely places them together, then does Gram Schmidt to find a new basis, then finds the transfer to that basis, then sum covariances and de-project to the basis.

#todo We know: lstsq is backprop-able by autograd.

#Till 18:30 work on it



from nppc.nppc import gram_schmidt
from torch.nn.functional import pad

example = 0
w_mat_steps = tuple(w[example, :, 0].flatten(1) for w in w_mat_intermed)
w_norms_steps = tuple(torch.linalg.norm(w, axis=1) for w in w_mat_steps)

# Get shared basis
w_mat_stack = torch.cat(w_mat_steps)
shared = gram_schmidt(w_mat_stack[None])[0]

# Define coordinates of bases in these
n_steps = len(w_mat_intermed)           #todo This is going to be the number of steps in MoDL
left_padding = lambda step: step * nppc_params.n_dirs
right_padding = lambda step: (n_steps - step - 1) * nppc_params.n_dirs
left_pads = list(map(left_padding, range(n_steps)))
right_pads = list(map(right_padding, range(n_steps)))
pad_mat = lambda W, left, right: pad(W, (0, 0, left, right))
w_mat_steps = tuple(map(pad_mat, w_mat_steps, left_pads, right_pads))
w_norms_steps = tuple(pad(w_norms_steps[step], (left_pads[step], right_pads[step])) for step in range(n_steps))


# selection = lambda step: (step * nppc_params.n_dirs, (step + 1) * nppc_params.n_dirs)
# sels = list(map(selection, range(n_steps)))
# w_mat_steps = tuple(pad(w_mat_stack[s[0]:s[1]], (0, 0, l, r)) for s, l, r in zip(sels, left_pads, right_pads))

# Represent covariances with that basis
covs_by_shared = list()
for step, norms in enumerate(w_norms_steps):
    trans_pcs_to_shared = torch.linalg.lstsq(shared.T, w_mat_steps[step].T).solution.T
    cov_by_pcs = torch.diag(norms)
    covs_by_shared.append(trans_pcs_to_shared.T @ cov_by_pcs @ trans_pcs_to_shared)

# Get a total covariance
total_cov_by_shared = torch.stack(covs_by_shared).sum(0)

# Get total PCA
pca_vals, pca_vecs_by_shared = torch.linalg.eigh(total_cov_by_shared)
argsort_vecs = torch.argsort(-pca_vals)
pca_vals = pca_vals[argsort_vecs]
pca_vecs_by_shared = pca_vecs_by_shared[argsort_vecs]

# Transform to pixel domain
dim1, dim2 = w_mat_intermed[0].shape[-2:]
pca_vecs = torch.einsum('bi, bc -> ci', shared, pca_vecs_by_shared).reshape(shared.shape[0], dim1, dim2).flip(0)
# trans_shared_to_pixel = torch.linalg.lstsq(shared.T, )
# pca_vec = 



#     trans_0_to_shared = torch.linalg.lstsq(basis, w_mat[0].T).solution.T
# cov_by_0 = torch.diag(w_norms[0])
# cov_from__by_shared = trans_0_to_shared.T @ cov_by_0 @ trans_0_to_shared
# 

# U, sigma, Vt = torch.linalg.svd(w_mat_stack)

# Enforce

# %%
w_mat_steps[0].T.shape
# Out:
# torch.Size([372, 377, 1, 5])

# %%
""" Display the PCs """
import matplotlib.pyplot as plt

sample = 0
mmse = preproc(x_intermed, -1)[sample, 0]

# Showing all PCs
n = 20 #10
fig, ax = plt.subplots(1, n + 1, sharex=True, sharey=True)
ax[0].imshow(mmse, vmin=0, vmax=1.5, cmap='Greys_r', origin='lower')
for c in range(n):
    ax[c + 1].set_title(f'PC {c + 1}\nEig. val. {pca_vals[c]}')
    ax[c + 1].imshow(pca_vecs[c], vmin=-0.2, vmax=0.2, cmap='RdBu', origin='lower')
# fig.set_size_inches(20, 6)
fig.set_size_inches(70, 10)
fig.tight_layout()
fig.savefig('/home/alon_granek/PythonProjects/NPPC/NPPC random walk PCs (first 6 steps out of 8).png')
# fig.show()
# Out:
# <div id='60cf527c-d88e-48b0-b07f-070ac5f4d046'></div>

# %%
mmse.shape
# Out:
# torch.Size([2, 1, 372, 372])

# %%
""" Attempt in rough skull stripping """

from alon.brain_masking import BrainMasker

mask = BrainMasker()(recon_image[sample])[0]

# %% [markdown]
# # Connecting MoDL to NPPC
#
# **Naive approach:** Use the whole unrolled network for PC estimation. The PC subspace is expected to be data consistent, as there is no variance on the projection of k-space one-hot vectors corresponding to the measured k's.

# %%
from nppc_architecture import UNet
from nppc import PCWrapper

n_dirs = 5

# Initialize frozen sampling mask
for iter, data in enumerate(train_loader):
    mask = data[-1].to(device)
    mask_ifft = torch.fft.ifft2(torch.fft.ifftshift(mask, axis=(1, 2)), axis=(1, 2))
    break

nppc_net = PCWrapper(UNet(in_channels=1 + 1, out_channels=1 * n_dirs), n_dirs=n_dirs) #, mask_ifft=mask_ifft) #, mask=1) #mask)
nppc_net.__setattr__('ddp', Namespace(size=1))

nppc_net.to(device)
nppc_net.train()
nppc_optimizer = torch.optim.Adam(
    nppc_net.parameters(), lr=1e-4, #lr=1e-5,
    betas=(0.9, 0.999)
)
nppc_step = 0

restoration_n_steps = 4000 #1000 #3000
nppc_n_steps = 3000 #3000
batch_size = 8 #2 #64 #128 #64 #128       #256

second_moment_loss_lambda = 1e0 #0.2 #1e0
second_moment_loss_grace = 500
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/usr/lib/python3.10/shutil.py", line 731, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.10/shutil.py", line 729, in rmtree
#     os.rmdir(path)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-o5q0m1nh'

# %%
from dataclasses import dataclass
from typing import Tuple


@dataclass
class NPPCParams:
    # Inference params
    n_dirs: int = 5
    nppc_step: int = 0
    restoration_n_steps: int = 4000
    nppc_n_steps: int = 3000
    
    # Train params
    #   How many samples to apply NPPC in parallel to
    parallel_est_size: int = 8
    #   How many parallel runs, to define as a batch? On each batch, we do a backprop.
    batch_size: int = 4
    #   Loss components
    second_moment_loss_lambda: float = 1e0
    second_moment_loss_grace: float = 500
    #       Data consistency loss component. Set to 0 if we don't want to calculate it
    dc_loss_lambda: float = 5e0 #1e0


train_loader_given_mask = create_data_loaders(params, frozen_mask=mask)


class NPPCForMoDLWrapper:
    def __init__(self, nppc_params: NPPCParams, modl: UnrolledModel = single_MoDL):
        self.nppc_params = nppc_params
        self.nppc_net = PCWrapper(UNet(in_channels=1 + 1, out_channels=1 * self.nppc_params.n_dirs), n_dirs=self.nppc_params.n_dirs) #, mask_ifft=mask_ifft)
        self.nppc_net.__setattr__('ddp', Namespace(size=1))
        self.nppc_net.to(device)
        self.nppc_net.train()
        self.nppc_optimizer = torch.optim.Adam(
            self.nppc_net.parameters(), lr=1e-4, #lr=1e-5,
            betas=(0.9, 0.999)
        )
        
        self.modl = modl
    
    def __call__(self):
        return
    
    def train(self, ):
        for rep in range(20): #12):
            start = repeats * rep
            losses = list()
            for iter, data in enumerate(train_loader_given_mask, start=start):
                print(f'Iter {iter}...')
                losses.append(get_batch_loss(data))
                if iter - start == repeats - 1:
                    break
            
            objective = torch.stack(losses).mean()
            
            # enum_lim = islice(enumerate(train_loader_given_mask, start=repeats * rep), repeats)
            # objective = torch.mean(torch.tensor([get_batch_loss(data) for iter, data in enum_lim]))
            nppc_optimizer.zero_grad()
            objective.backward() #retain_graph=True)
            nppc_optimizer.step()
            nppc_step += 1
        
            print(f'Loss: {objective.detach().item()}')
        
            torch.save(nppc_net, f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net_DCed2test.pth')

        return
    
    def get_batch_loss(self, data: Tuple[torch.Tensor, torch.Tensor, torch.Tensor], nppc_position: int = 0):
        """
        
        :param data: 
        :param nppc_position:       Position of input to the NPPC (not position of the MMSE)
        :return: 
        """
        assert nppc_position < params.num_grad_steps, f'Chosen NPPC placement ({nppc_position}) is out of bounds, not in [0, {params.num_grad_steps} - 1]'
        
        # Unpack training data: subsampled k-space, target image, k-space mask
        y, x_true, mask = (obj.to(device) for obj in data)
                
        # Reconstruct, apply NPPC, calculate image-domain error
        with torch.no_grad():
            x_recon, x_intermed = self.modl(y.float(), mask=mask, return_steps=True)
        print('\tReconstructed')
        
        step_input = cplx.abs(x_intermed[nppc_position])[:, None, ...]
        step_mmse = cplx.abs(x_intermed[nppc_position - 1])[:, None, ...]
        w_mat = nppc_net(step_input, step_mmse)
        print('\tEstimated principal components')
        
        w_mat_ = w_mat.flatten(2)
        w_norms = w_mat_.norm(dim=2)
        w_hat_mat = w_mat_ / w_norms[:, :, None]
        
        x_true = cplx.abs(x_true.detach())[:, None, ...]
        err = (x_true - step_mmse).flatten(1)
                
        ## Normalizing by the error's norm
        ## -------------------------------
        err_norm = err.norm(dim=1)
        err = err / err_norm[:, None]
        w_norms = w_norms / err_norm[:, None]
        
        ## W hat loss
        ## ----------
        err_proj = torch.einsum('bki,bi->bk', w_hat_mat, err)
        reconst_err = 1 - err_proj.pow(2).sum(dim=1)
        
        ## W norms loss
        ## ------------
        second_moment_mse = (w_norms.pow(2) - err_proj.detach().pow(2)).pow(2)
        
        ## (Alon, ShimronLab) Data-consistency loss
        ## ----------------------------------------
        dc_loss = 0
        if self.nppc_params.dc_loss_lambda != 0:
            MFW = torch.einsum(
                'cije, edij -> ec',
                mask, abs(torch.fft.fftshift(torch.fft.fft2(w_mat[:, :, 0], axis=(1, 2)), axis=(1, 2)))
            ) / (2 * err.size()[1])           # c: Re/Im component, i,j: image dims, e: example, d: PC directions
            dc_loss = torch.linalg.norm(MFW) / (MFW.shape[0] * MFW.shape[1])
        
        second_moment_loss_lambda = -1 + 2 * nppc_step / second_moment_loss_grace
        second_moment_loss_lambda = max(min(second_moment_loss_lambda, 1) ,1e-6)
        second_moment_loss_lambda *= second_moment_loss_lambda
        
        loss = reconst_err.mean() + second_moment_loss_lambda * second_moment_mse.mean() + self.nppc_params.dc_loss_lambda * dc_loss
        return loss
        
    def reset(self, nppc_params: NPPCParams = None):
        self.__init__(self.nppc_params if nppc_params is None else nppc_params)


repeats = 4
batch_objectives = torch.zeros(repeats, dtype=torch.float32)


def get_batch_loss(data, nppc_position: int = 0):
    """
    
    :param data: 
    :param nppc_position:       Position of input to the NPPC (not position of the MMSE)
    :return: 
    """
    assert nppc_position < params.num_grad_steps, f'Chosen NPPC placement ({nppc_position}) is out of bounds, not in [0, {params.num_grad_steps} - 1]'
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y, x_true, mask = data
    x_true = x_true.to(device)
    mask = mask.to(device)
    y = y.to(device)
    
    with torch.no_grad():
        x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
        print('\tReconstructed')
        
    # Input to NPPC: The n-1-th iteration solution as input, and n-th iteration solution as the MMSE
    # mmse = cplx.abs(x_recon)[:, None, ...]
    step_input = cplx.abs(x_intermed[nppc_position])[:, None, ...]
    step_mmse = cplx.abs(x_intermed[nppc_position - 1])[:, None, ...]
    # w_mat = nppc_net(problem_input, mmse)
    w_mat = nppc_net(step_input, step_mmse)
    
    w_mat_ = w_mat.flatten(2)
    w_norms = w_mat_.norm(dim=2)
    w_hat_mat = w_mat_ / w_norms[:, :, None]
    
    x_true = cplx.abs(x_true.detach())[:, None, ...]
    err = (x_true - step_mmse).flatten(1)
    
    print('\tCalculated error')

    ## Normalizing by the error's norm
    ## -------------------------------
    err_norm = err.norm(dim=1)
    err = err / err_norm[:, None]
    w_norms = w_norms / err_norm[:, None]
    
    ## W hat loss
    ## ----------
    err_proj = torch.einsum('bki,bi->bk', w_hat_mat, err)
    reconst_err = 1 - err_proj.pow(2).sum(dim=1)
    
    ## W norms loss
    ## ------------
    second_moment_mse = (w_norms.pow(2) - err_proj.detach().pow(2)).pow(2)
    
    ## (Alon, ShimronLab) Data-consistency loss
    ## ----------------------------------------
    # print('\tCalculating DC loss')
    # MW = torch.einsum('cije, edij -> ec', mask_ifft.float(), w_mat[:, :, 0].float()) / (2 * err.size()[1])           # c: Re/Im component, i,j: image dims, e: example, d: PC directions
    MFW = torch.einsum(
        'cije, edij -> ec',
        mask, abs(torch.fft.fftshift(torch.fft.fft2(w_mat[:, :, 0], axis=(1, 2)), axis=(1, 2)))
    ) / (2 * err.size()[1])           # c: Re/Im component, i,j: image dims, e: example, d: PC directions
    dc_loss = torch.linalg.norm(MFW) / (MFW.shape[0] * MFW.shape[1])
    dc_loss_lambda = 5e0 #1e0
    
    second_moment_loss_lambda = -1 + 2 * nppc_step / second_moment_loss_grace
    second_moment_loss_lambda = max(min(second_moment_loss_lambda, 1) ,1e-6)
    second_moment_loss_lambda *= second_moment_loss_lambda
    
    return reconst_err.mean() + second_moment_loss_lambda * second_moment_mse.mean() + dc_loss_lambda * dc_loss

# %% [markdown]
# ## DAPA 2: Run on the last step in MoDL
# **Rationale**
# 1. This is where **x** enters the true solution space
# 2. This is the smallest problem where uncertainty still exists (we trust the previous steps in MoDL)
# 3. It is a much easier problem

# %%
from alon.brain_masking import BrainMasker

# %%
for iter, data in enumerate(train_loader):
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y, x_true, mask = data
    x_true = x_true.to(device)
    mask = mask.to(device)
    y = y.to(device)
        
    with torch.no_grad():
        x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
    
        # Input to NPPC: The n-1-th iteration solution as input, and n-th iteration solution as the MMSE
        mmse = cplx.abs(x_recon)[:, None, ...]
        problem_input = cplx.abs(x_intermed[-1])[:, None, ...]
        w_mat_orig = nppc_net(problem_input, mmse)
    
    """ Test - defining the error only on the masked image """
    # mask = BrainMasker()(mmse[0, 0])[0]#.flatten()
    # err *= mask[None]
    
    # w_mat = w_mat_orig * torch.tensor(BrainMasker()(mmse[0, 0])[0][None, None, None], dtype=torch.float32)
    w_mat = w_mat_orig
    """"""
    
    
    w_mat_ = w_mat.flatten(2)
    w_norms = w_mat_.norm(dim=2)
    w_hat_mat = w_mat_ / w_norms[:, :, None]
    
    x_true = cplx.abs(x_true.detach())[:, None, ...]
    err = (x_true - mmse).flatten(1)
    

    ## Normalizing by the error's norm
    ## -------------------------------
    err_norm = err.norm(dim=1)
    err = err / err_norm[:, None]
    w_norms = w_norms / err_norm[:, None]
    
    ## W hat loss
    ## ----------
    err_proj = torch.einsum('bki,bi->bk', w_hat_mat, err)
    reconst_err = 1 - err_proj.pow(2).sum(dim=1)
    
    ## W norms loss
    ## ------------
    second_moment_mse = (w_norms.pow(2) - err_proj.detach().pow(2)).pow(2)
    
    second_moment_loss_lambda = -1 + 2 * nppc_step / second_moment_loss_grace
    second_moment_loss_lambda = max(min(second_moment_loss_lambda, 1) ,1e-6)
    second_moment_loss_lambda *= second_moment_loss_lambda
    objective = reconst_err.mean() + second_moment_loss_lambda * second_moment_mse.mean()

    nppc_optimizer.zero_grad()
    objective.backward()
    nppc_optimizer.step()
    nppc_step += 1
    
    
    print(f'Loss: {objective.detach().item()}')
    
    torch.save(nppc_net, f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net3.pth')
# Out:
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.825690746307373
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.904462993144989
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8065555095672607
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8409633040428162
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.7346203327178955
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.752144455909729
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8610484600067139
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.7396346926689148
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8439711332321167
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8512775897979736
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.735094428062439
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.8334081172943115
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.7661327123641968
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# Loss: 0.7712322473526001
# 		Step 0/3...
# 		Step 1/3...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 10
#       7 y = y.to(device)
#       9 with torch.no_grad():
# ---> 10     x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
#      12 # Input to NPPC: The n-1-th iteration solution as input, and n-th iteration solution as the MMSE
#      13 mmse = cplx.abs(x_recon)[:, None, ...]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/MoDL_single.py:109, in UnrolledModel.forward(self, kspace, init_image, mask, return_steps)
#     107             image = image.permute(0,3,1,2)
#     108 #             pl.ImagePlot(image.detach().cpu())
# --> 109             image = resnet(image)
#     110             image = image.permute(0,2,3,1)
#     111             rhs = zf_image + self.modl_lamda * image
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_model.py:30, in UNet.forward(self, x)
#      28 x = self.up2(x, x3)
#      29 x = self.up3(x, x2)
# ---> 30 x = self.up4(x, x1)
#      31 x = self.outc(x)
#      32 return F.sigmoid(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_parts.py:77, in up.forward(self, x1, x2)
#      72 # for padding issues, see
#      73 # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
#      74 # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
#      76 x = torch.cat([x2, x1], dim=1)
# ---> 77 x = self.conv(x)
#      78 return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/alon/MoDLsinglechannel/demo_modl_singlechannel/unet/unet_parts.py:22, in double_conv.forward(self, x)
#      21 def forward(self, x):
# ---> 22     x = self.conv(x)
#      23     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# ## DAPA 2.1: On last MoDL step, but enforcing data consistency
#
# It is hard not to train the posterior of the absolute value clean image given the absolute value sampling-noised image. That's why I do so in DAPA 2.
#
# However, this degenerates the problem to a simple denoising problem, and so nothing makes the predicted PC subspace data-consistent, while it should be just that.
#
# * Not entirely though. Since we train on the last MoDL iteration, the k-space interpolation is almost fully done. There is simply larger uncertainty where not measured vs where measured.
#
# DAPA 2.1 attempts to continue learning on the absolute-values inverse problem, but ensure data-consistency on the PC subspace. That is in the hope that the only denoising done here is on the sampling noise.
#
# We look for an inverse problem of the form
#
# $$
# \underset{\mathbf x}{\arg \min} \|\mathbf{MF}(\hat{\mathbf x} + \mathbf W \boldsymbol \alpha) - \mathbf y\|^2 + \lambda R(\hat{\mathbf x} + \mathbf W \boldsymbol \alpha)
# $$
#
# $\hat{\mathbf x}\quad$      MMSE estimate
# $\mathbf W\quad$            Predicted PCs
# $\boldsymbol \alpha\quad$   Coordinates with respect to PCs. Let any such coordinates.
#
# Specifically for DC,
# $$
# \|\mathbf{MF}(\hat{\mathbf x} + \mathbf W \boldsymbol \alpha) - \mathbf y\|^2 \leq \|\mathbf{MF}\hat{\mathbf x} - \mathbf y\|^2 + \|\mathbf{MF}\mathbf W \boldsymbol \alpha\|^2
# $$
# Where the first term is already minimized by MoDL and is independent of PCs. We will attempt to add a $\|\mathbf{MW}\|^2$ loss.
#
#
# **A major change is that we freeze the mask to properly train the NPPC for this inverse problem**

# %%
train_loader_given_mask = create_data_loaders(params, frozen_mask=mask)
# Out:
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002641.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003008.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000508.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000531.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_203_6000942.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_209_6001397.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002033.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002392.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002668.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002683.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002862.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000269.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000657.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000760.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050102.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050159.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050255.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070034.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070133.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070786.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080154.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080240.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080576.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001236.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002047.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002128.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000860.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000196.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000217.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_209_6001122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001893.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002836.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020109.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020509.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000312.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000175.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000360.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000566.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000600.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002012.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002158.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002465.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002601.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010014.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010174.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010323.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010455.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010602.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020272.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020331.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030254.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040009.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040011.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040073.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050244.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060070.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060079.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070325.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070422.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070777.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090266.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001317.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001432.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001459.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100311.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100368.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001515.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001518.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001546.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001651.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001694.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001909.h5.npy...
# 99

# %%
repeats = 4
batch_objectives = torch.zeros(repeats, dtype=torch.float32)


def get_batch_loss(data, nppc_position: int = 0):
    """
    
    :param data: 
    :param nppc_position:       Position of input to the NPPC (not position of the MMSE)
    :return: 
    """
    assert nppc_position < params.num_grad_steps, f'Chosen NPPC placement ({nppc_position}) is out of bounds, not in [0, {params.num_grad_steps} - 1]'
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y, x_true, mask = data
    x_true = x_true.to(device)
    mask = mask.to(device)
    y = y.to(device)
    
    with torch.no_grad():
        x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
        print('\tReconstructed')
        
    # Input to NPPC: The n-1-th iteration solution as input, and n-th iteration solution as the MMSE
    # mmse = cplx.abs(x_recon)[:, None, ...]
    step_input = cplx.abs(x_intermed[nppc_position])[:, None, ...]
    step_mmse = cplx.abs(x_intermed[nppc_position - 1])[:, None, ...]
    # w_mat = nppc_net(problem_input, mmse)
    w_mat = nppc_net(step_input, step_mmse)
    
    w_mat_ = w_mat.flatten(2)
    w_norms = w_mat_.norm(dim=2)
    w_hat_mat = w_mat_ / w_norms[:, :, None]
    
    x_true = cplx.abs(x_true.detach())[:, None, ...]
    err = (x_true - step_mmse).flatten(1)
    
    print('\tCalculated error')

    ## Normalizing by the error's norm
    ## -------------------------------
    err_norm = err.norm(dim=1)
    err = err / err_norm[:, None]
    w_norms = w_norms / err_norm[:, None]
    
    ## W hat loss
    ## ----------
    err_proj = torch.einsum('bki,bi->bk', w_hat_mat, err)
    reconst_err = 1 - err_proj.pow(2).sum(dim=1)
    
    ## W norms loss
    ## ------------
    second_moment_mse = (w_norms.pow(2) - err_proj.detach().pow(2)).pow(2)
    
    ## (Alon, ShimronLab) Data-consistency loss
    ## ----------------------------------------
    # print('\tCalculating DC loss')
    # MW = torch.einsum('cije, edij -> ec', mask_ifft.float(), w_mat[:, :, 0].float()) / (2 * err.size()[1])           # c: Re/Im component, i,j: image dims, e: example, d: PC directions
    MFW = torch.einsum(
        'cije, edij -> ec',
        mask, abs(torch.fft.fftshift(torch.fft.fft2(w_mat[:, :, 0], axis=(1, 2)), axis=(1, 2)))
    ) / (2 * err.size()[1])           # c: Re/Im component, i,j: image dims, e: example, d: PC directions
    dc_loss = torch.linalg.norm(MFW) / (MFW.shape[0] * MFW.shape[1])
    dc_loss_lambda = 5e0 #1e0
    
    second_moment_loss_lambda = -1 + 2 * nppc_step / second_moment_loss_grace
    second_moment_loss_lambda = max(min(second_moment_loss_lambda, 1) ,1e-6)
    second_moment_loss_lambda *= second_moment_loss_lambda
    
    return reconst_err.mean() + second_moment_loss_lambda * second_moment_mse.mean() + dc_loss_lambda * dc_loss

# %%
""" Training """

for rep in range(20): #12):
    start = repeats * rep
    losses = list()
    for iter, data in enumerate(train_loader_given_mask, start=start):
        print(f'Iter {iter}...')
        losses.append(get_batch_loss(data))
        if iter - start == repeats - 1:
            break
    
    objective = torch.stack(losses).mean()
    
    # enum_lim = islice(enumerate(train_loader_given_mask, start=repeats * rep), repeats)
    # objective = torch.mean(torch.tensor([get_batch_loss(data) for iter, data in enum_lim]))
    nppc_optimizer.zero_grad()
    objective.backward() #retain_graph=True)
    nppc_optimizer.step()
    nppc_step += 1

    print(f'Loss: {objective.detach().item()}')

    torch.save(nppc_net, f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net_DCed2test.pth')

# %%
nppc_net = torch.load(
    # f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net3.pth'
    #f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net_DCed.pth'
    f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net_DCed2test.pth'
)

for iter, data in enumerate(train_loader_given_mask):
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y, x_true, mask = data
    x_true = x_true.to(device)
    mask = mask.to(device)
    y = y.to(device)
        
    with torch.no_grad():
        x_recon, x_intermed = single_MoDL(y.float(), mask=mask, return_steps=True)
    
    # Input to NPPC: The n-1-th iteration solution as input, and n-th iteration solution as the MMSE
    mmse = cplx.abs(x_recon)[:, None, ...]
    problem_input = cplx.abs(x_intermed[-1])[:, None, ...]
    w_mat = nppc_net(problem_input, mmse)
    
    break
# Out:
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...

# %%
from alon.MoDLsinglechannel.demo_modl_singlechannel.utils.transforms import SenseModel_single

fig, ax = plt.subplots(1, 2, sharex=True, sharey=True)
# ax[0].imshow(cplx.abs(x_intermed[0])[1])
ax[0].imshow(problem_input[1, 0])
ax[1].imshow(mmse[1, 0])
# Out:
# <div id='a7bcc283-6897-4f08-b2fa-4a0dafb839ab'></div>

# %%
""" Analysis of PCs in k-space - as they should all be 0 where not measured """
from alon.fastmri_preprocess import fftc, ifftc
import matplotlib.pyplot as plt

c = 4
example = 1

y_c = fftc(w_mat[example, c, 0].detach().numpy())
log_y_c = 10 * np.log10(abs(y_c))
m = mask[0, ..., example].detach().numpy().astype(bool)

# plt.figure()
# plt.hist([log_y_c[m], log_y_c[~m]], histtype='step', label=['measured', 'not measured'], density=True, bins=50)
# plt.legend()


fig, ax = plt.subplots(1, 2)
ax[0].imshow(ifftc(y_c * (1 - m)).real, vmin=-0.1, vmax=0.1, cmap='RdBu')
ax[0].set_title('zeroed')
ax[1].imshow(w_mat[example, c, 0].detach().numpy(), vmin=-0.1, vmax=0.1, cmap='RdBu')
ax[1].set_title('raw')
# Out:
# <div id='b210b19c-a301-4a59-84ad-5d7c2db6c887'></div>
# Text(0.5, 1.0, 'raw')

# %%
mask.shape
# Out:
# torch.Size([2, 372, 372, 2])

# %%
import matplotlib.pyplot as plt
# fig, ax = plt.subplots(1, 5)
# for c in range(5):
#     ax[c].imshow(w_mat[0, c, 0], cmap='inferno', origin='lower', vmin=-0.5, vmax=0.5)
# fig.set_size_inches(13, 5)

c = 0
alphas = np.linspace(-0.1, 0.1, 5)
fig, ax = plt.subplots(1, len(alphas))
for i, alpha in enumerate(alphas):
    ax[i].imshow(mmse.detach()[0, 0] + alpha * w_mat.detach()[0, c, 0], cmap='Greys_r', origin='lower', vmin=0, vmax=1.5)
fig.set_size_inches(30, 7)
fig.tight_layout()
fig.savefig('/home/alon_granek/PythonProjects/NPPC/temp.png')
# Out:
# <div id='cb7855c5-3e00-4f0d-95eb-b7c2ed4e5a0c'></div>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# List of image file paths

# Initial image index
current_image_index = 0

c = 3
alphas = np.linspace(-1, 1, 4)

# Function to display the image at the current index
def display_image():
    img = mmse.detach()[0, 0] + alphas[current_image_index] * w_mat.detach()[0, c, 0] #mpimg.imread(image_files[current_image_index])
    ax.imshow(img, cmap='Greys_r', vmin=0, vmax=1.5, origin='lower')
    ax.set_title(f"Alpha {round(alphas[current_image_index], 2)}")
    fig.canvas.draw()

# Function to handle key press events
def on_key(event):
    global current_image_index
    if event.key == 'up':
        current_image_index = (current_image_index + 1) % alphas.size #len(image_files)
    elif event.key == 'down':
        current_image_index = (current_image_index - 1) % alphas.size #len(image_files)
    display_image()

# Create a figure and axis
fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.2)
fig.set_size_inches(10, 10)
fig.tight_layout()

# Display the initial image
display_image()

# Connect the key press event to the handler
fig.canvas.mpl_connect('key_press_event', on_key)

# Display the plot
plt.show()
# Out:
# <div id='641f83d0-004d-43b1-a1ff-2978030b6e5d'></div>

# %%
""" Showing all PCs """

import matplotlib.pyplot as plt

example = 1

fig, ax = plt.subplots(1, 5)
for c in range(5):
    ax[c].set_title(f'PC {c + 1}')
    # ax[c].imshow(w_mat.detach()[example, c, 0] - w_mat.detach()[example, c, 0].mean(), vmin=-0.2, vmax=0.2, cmap='RdBu')
    ax[c].imshow(w_mat.detach()[example, c, 0], vmin=-0.2, vmax=0.2, cmap='RdBu')
fig.set_size_inches(20, 6)
# fig.set_size_inches(10, 5)
fig.tight_layout()
fig.savefig('/home/alon_granek/PythonProjects/NPPC/temp2.png')
# Out:
# <div id='ad7475f9-a5dd-411f-8527-c18a37c26bc0'></div>

# %%
from alon.fastmri_preprocess import fftc, ifftc

example = 1

fig, ax = plt.subplots(1, 5)
for c in range(5):
    ax[c].set_title(f'PC {c + 1}')
    ax[c].imshow(10 * np.log10(abs(fftc(w_mat.detach()[example, c, 0]))), cmap='magma')
fig.set_size_inches(20, 6)
# fig.set_size_inches(10, 5)
fig.tight_layout()
# fig.savefig('/home/alon_granek/PythonProjects/NPPC/pc kspace.png')
# Out:
# <div id='91a24dee-0d8b-48b0-b5e4-78a999290c34'></div>

# %%
# Orthogonallity test

# for c in range(5):
#     w = w_mat[:, c]
#     dot = torch.einsum('ecij, ecij -> ec', mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0], w_mat[:, :, 0])
#     norm_w = torch.einsum('ecij, ecij -> ec', w_mat[:, :, 0], w_mat[:, :, 0])
#     norm_m = torch.einsum('ecij, ecij -> ec', mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0], mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0])
#     print(
#         f'{dot=}\n\n{norm_w=}\n\n{norm_m=}'
#     )
    
# mask_ifft.shape, w_mat.shape

from alon.MoDLsinglechannel.demo_modl_singlechannel.utils.flare_utils import torch_fft2c

c = 0
ex = 0

fig, ax = plt.subplots()
# ax.imshow(10 * np.log10(abs(torch.fft.fftshift(torch.fft.fft2(w_mat[ex, c, 0])).detach())))
# ax.imshow(10 * np.log10(abs(torch.fft.fftshift(torch.fft.fft2(mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0])).detach()))[ex, 0])
ax.imshow(10 * np.log10(abs(torch.fft.fft2(mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0])).detach())[ex, 0])
# ax.imshow(mask_ifft[0].real.permute(2, 0, 1)[:, None, None][:, :, 0].detach()[ex, 0], vmin=-1, vmax=1)

# %%
# Animation of adding or removing the PC
import matplotlib.pyplot as plt
import matplotlib.animation as animation

c = 2
example = 1

# Create a sample 3D array (e.g., 10 slices of 2D images)
alphas = np.linspace(-1, 1, 50)
image_series = mmse.detach()[example, 0][None] + alphas[:, None, None] * (w_mat.detach().numpy()[example, c, 0] - w_mat.detach().numpy()[example, c, 0].mean())[None]
# mask = BrainMasker()(mmse.detach()[0, 0].numpy())

# Set up the figure and axis
fig, ax = plt.subplots()
im = ax.imshow(image_series[0], cmap='Greys_r', vmin=0, vmax=1.5)
fig.set_size_inches(10, 10)

def update(frame):
    # Update the image data
    ax.set_title(round(alphas[frame], 2))
    im.set_array(image_series[frame]) # * mask)
    return [im]

# Create animation
ani = animation.FuncAnimation(fig, update, frames=alphas.size, repeat=True, interval=30)

# Display the animation
# plt.show()
FFwriter = animation.FFMpegWriter(fps=10)
ani.save('/home/alon_granek/PythonProjects/NPPC/ani3.avi', writer=FFwriter)
# Out:
# <div id='7e50f22a-debb-46e8-93dd-4321e716a778'></div>
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 1000x1000 -pix_fmt rgba -r 10 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /home/alon_granek/PythonProjects/NPPC/ani3.avi

# %% [markdown]
# **Test of data consistency**

# %%
from alon.fastmri_preprocess import fftc

c = 4 #0
example = 1
# alphas = np.linspace(-1, 1, 100)
# image_series = mmse.detach()[example, 0][None] + alphas[:, None, None] * w_mat.detach().numpy()[example, c, 0][None]

# Sample
sigma = 2 #0.05
n_samples = 200 #100
samples = sigma * np.random.normal(0, 1, [n_dirs, n_samples])
# sample_images = mmse.detach()[example, 0] + alphas[:, None] * w_mat.detach().numpy()[example, :, 0]
sample_images = mmse.detach()[example, 0] + np.einsum('cs, cij -> sij', samples, w_mat.detach().numpy()[example, :, 0])

# Check data consistency
y_nppc_samples = fftc(sample_images)
# dc = np.linalg.norm(mask[0][None, ..., example] * y_nppc_samples - (y[0] + 1j * y[1]).detach().numpy()[..., example], axis=(1, 2))
dc = np.linalg.norm(mask[0][None, ..., example] * y_nppc_samples - (y[0] + 1j * y[1]).detach().numpy()[..., example], axis=(1, 2))

# %%
dc_mmse = np.linalg.norm(mask[0][..., example] * mmse.detach()[example, 0] - (y[0] + 1j * y[1]).detach().numpy()[..., example])

plt.figure()
plt.hist(dc, bins=50)
plt.axvline(dc_mmse, color='black')
# Out:
# <div id='39f0e72a-cc54-426b-8d34-6ea50e7f6606'></div>

# %%
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True)
ax[0].imshow(sample_images[dc.argmin()], vmin=0)
ax[1].imshow(x_true[example, ..., 0], vmin=0)
fig.set_size_inches(13, 8)
# Out:
# <div id='b128fc9f-184e-44ec-bb0b-2fa97a4c1785'></div>

# %%
c = 3


# Create a sample 3D array (e.g., 10 slices of 2D images)
alphas = np.linspace(-0.5, 0.5, 10)
image_series = mmse.detach()[0, 0][None] + alphas[:, None, None] * w_mat.detach().numpy()[0, c, 0][None]
mask = BrainMasker()(mmse.detach()[0, 0].numpy())

fig, ax = plt.subplots()
im = ax.imshow(image_series[0], cmap='Greys_r', vmin=0, vmax=1.5)

def update(frame):
    # Update the image data
    ax.set_title(round(alphas[frame], 2))
    im.set_array(image_series[frame]) # * mask)
    return [im]

for i in range(image_series.shape[0]):
    update(i)

fig.set_size_inches(10, 10)
plt.show()
# Out:
# <div id='43733502-ba33-4bb4-9309-f09f047246ee'></div>

# %%
fig.savefig('/home/alon_granek/PythonProjects/NPPC/PCs 2.png')

# %% [markdown]
# # DAPA 2.1.1: Posterior-to-posterior mapping via a point-to-posterior mapping

# %%
#todo Train network per step. Inference: Get mean, PCs per step, then sample a sphere, get total mean, covariance, then advance. Check if converges

# %%
""" Training """

modl_steps = np.arange(0, params.num_grad_steps)

for step in modl_steps:
    print(f'TRAINING ON MODL GRADIENT STEP {step}-{step + 1}')
    for rep in range(15): #12):
        start = repeats * rep
        losses = list()
        for iter, data in enumerate(train_loader_given_mask, start=start):
            print(f'Iter {iter}...')
            losses.append(get_batch_loss(data, step))
            if iter - start == repeats - 1:
                break
        
        objective = torch.stack(losses).mean()        
        nppc_optimizer.zero_grad()
        objective.backward() #retain_graph=True)
        nppc_optimizer.step()
        nppc_step += 1
    
        print(f'Loss: {objective.detach().item()}')
    
        torch.save(nppc_net, f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net_DCed step {step}.pth')
# Out:
# TRAINING ON MODL GRADIENT STEP 0-1
# Iter 0...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 1...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 2...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 3...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 10.983609199523926
# Iter 4...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 5...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 6...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 7...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 6.298846244812012
# Iter 8...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 9...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 10...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 11...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 4.612931251525879
# Iter 12...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 13...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 14...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 15...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 3.8963112831115723
# Iter 16...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 17...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 18...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 19...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 3.595676898956299
# Iter 20...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 21...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 22...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 23...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 3.055488348007202
# Iter 24...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 25...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 26...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 27...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.6986827850341797
# Iter 28...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 29...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 30...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 31...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.7685797214508057
# Iter 32...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 33...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 34...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 35...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.4548497200012207
# Iter 36...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 37...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 38...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 39...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.418017625808716
# Iter 40...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 41...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 42...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 43...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.3896756172180176
# Iter 44...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 45...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 46...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 47...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.2564384937286377
# Iter 48...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 49...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 50...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 51...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.091543674468994
# Iter 52...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 53...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 54...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 55...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 2.0763800144195557
# Iter 56...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 57...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 58...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 59...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.963900089263916
# TRAINING ON MODL GRADIENT STEP 1-2
# Iter 0...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 1...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 2...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 3...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.9593076705932617
# Iter 4...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 5...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 6...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 7...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.8544447422027588
# Iter 8...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 9...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 10...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 11...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.7927870750427246
# Iter 12...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 13...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 14...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 15...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.6523699760437012
# Iter 16...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 17...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 18...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 19...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.6715909242630005
# Iter 20...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 21...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 22...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 23...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.6603896617889404
# Iter 24...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 25...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 26...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Iter 27...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# 	Calculated error
# Loss: 1.692239761352539
# Iter 28...
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# 	Reconstructed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 12
#      10 for iter, data in enumerate(train_loader_given_mask, start=start):
#      11     print(f'Iter {iter}...')
# ---> 12     losses.append(get_batch_loss(data, step))
#      13     if iter - start == repeats - 1:
#      14         break
#
# Cell In[11], line 29, in get_batch_loss(data, nppc_position)
#      27 step_mmse = cplx.abs(x_intermed[nppc_position - 1])[:, None, ...]
#      28 # w_mat = nppc_net(problem_input, mmse)
# ---> 29 w_mat = nppc_net(step_input, step_mmse)
#      31 w_mat_ = w_mat.flatten(2)
#      32 w_norms = w_mat_.norm(dim=2)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/PythonProjects/NPPC/nppc/nppc.py:279, in PCWrapper.forward(self, x_distorted, x_restored)
#     276 if padding is not None:
#     277     x = F.pad(x, tuple(padding))
# --> 279 w_mat = self.net(x)
#     280 if self.scale is not None:
#     281     w_mat = w_mat * self.scale
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[8], line 82, in UNet.forward(self, x)
#      80 h = []
#      81 for block in self.encoder_blocks:
# ---> 82     x = block(x)
#      83     h.append(x)
#      85 x = self.bottleneck(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# ## DAPA 1: Run directly on the abs of input zero-filled and output

# %%
# from nppc import NPPCTrainer

# trainer = NPPCTrainer(
#     model=nppc_net,
#     batch_size=16,
#     max_chunk_size=8,
#     output_folder='./results/celeba_inpainting_eyes/nppc/',
#     max_benchmark_samples=256,
# )
# trainer.train(
#     n_steps=100, #20000,
#     log_every=20,
#     benchmark_every=None,
# )
from alon.fastmri_preprocess import ifftc, fftc

params_nppc = params
params_nppc.batch_size = 8
train_loader = create_data_loaders(params)


from IPython.display import display, clear_output

# fig, ax = plt.subplots()


nppc_objective_log = []
for iter, data in enumerate(train_loader):
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y_distorted, x_org, mask = data
    x_org = x_org.to(device)
    mask = mask.to(device)
    y_distorted = y_distorted.to(device)
    # Zero-filled image ("distorted" in NPPC terms)
    x_distorted = torch.tensor(abs(ifftc(torch.tensor(fftc(x_org[..., 0] + 1j * x_org[..., 1])) * mask[..., 0]))).to(device).float()[:, None, ...]
    # x_distorted = abs(ifftc(y_distorted[..., 0] + 1j * y_distorted[..., 1]))
    
    with torch.no_grad():
        x_restored = single_MoDL(y_distorted.float(), mask=mask)
        # x_distorted = x_distorted[None]
        
        # Moving the "sample in batch" axis to be the first
        # x_distorted = torch.permute(x_distorted, [3, 0, 1, 2])
        # x_restored = torch.permute(x_distorted, [3, 0, 1, 2])
        # 
        # print(x_distorted.shape)
        #w_mat = nppc_net(x_distorted.permute([3, 0, 1, 2]), x_restored.permute([3, 0, 1, 2]))
        
    # zero-filling of distorted    
    
    
    # x_distorted = cplx.abs(x_distorted.detach())[:, None, ...]
    x_restored = cplx.abs(x_restored.detach())[:, None, ...]
    print(f'{x_restored.shape=}\t\t{x_distorted.shape=}')
    # break
    w_mat = nppc_net(x_distorted, x_restored)

    w_mat_ = w_mat.flatten(2)
    w_norms = w_mat_.norm(dim=2)
    w_hat_mat = w_mat_ / w_norms[:, :, None]
    
    x_org = cplx.abs(x_org.detach())[:, None, ...]
    err = (x_org - x_restored).flatten(1)

    ## Normalizing by the error's norm
    ## -------------------------------
    err_norm = err.norm(dim=1)
    err = err / err_norm[:, None]
    w_norms = w_norms / err_norm[:, None]
    
    ## W hat loss
    ## ----------
    err_proj = torch.einsum('bki,bi->bk', w_hat_mat, err)
    reconst_err = 1 - err_proj.pow(2).sum(dim=1)
    
    ## W norms loss
    ## ------------
    second_moment_mse = (w_norms.pow(2) - err_proj.detach().pow(2)).pow(2)
    
    second_moment_loss_lambda = -1 + 2 * nppc_step / second_moment_loss_grace
    second_moment_loss_lambda = max(min(second_moment_loss_lambda, 1) ,1e-6)
    second_moment_loss_lambda *= second_moment_loss_lambda
    objective = reconst_err.mean() + second_moment_loss_lambda * second_moment_mse.mean()

    nppc_optimizer.zero_grad()
    objective.backward()
    nppc_optimizer.step()
    nppc_step += 1
    
    
    print(f'Loss: {objective.detach().item()}')
    
    
    if True: #nppc_step % 10 == 0:
        nppc_objective_log.append(objective.detach().item())

        torch.save(nppc_net, f'/home/alon_granek/PythonProjects/NPPC/modl_nppc_net.pth')

        # ax.clear()
        # ax.plot(nppc_objective_log)
        # display(fig)
# Out:
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_200_6002641.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_201_6003008.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000508.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_202_6000531.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_203_6000942.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXFLAIR_209_6001397.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002033.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_200_6002392.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002668.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002683.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_201_6002862.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_202_6000269.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000657.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_203_6000760.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050102.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050159.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_205_2050255.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070034.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070133.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070357.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_207_2070786.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080150.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080154.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080240.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080421.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_208_2080576.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1POST_209_6001236.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002047.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_200_6002128.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_203_6000860.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000196.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_206_6000217.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_209_6001122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1PRE_210_6001893.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002779.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_201_6002836.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020109.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020334.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_2020509.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT1_202_6000312.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000080.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000092.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000175.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000360.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000566.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_2000600.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6001972.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002012.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002158.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002465.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002539.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_200_6002601.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010014.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010174.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010201.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010261.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010323.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010455.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010519.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_201_2010602.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020116.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020272.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020290.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020331.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_202_2020365.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030122.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_203_2030254.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040009.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040011.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040073.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_204_2040086.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_2050244.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_205_6000022.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060070.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_206_2060079.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070090.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070325.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070422.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070590.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_207_2070777.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_208_2080585.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090077.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_2090266.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001317.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001432.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_209_6001459.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100311.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_2100368.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001515.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001518.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001524.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001546.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001651.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001694.h5.npy...
# 	/mnt/c/Users/along/brain_multicoil_train_batch_0/multicoil_train/file_brain_AXT2_210_6001909.h5.npy...
# 99
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8334869742393494
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8219723701477051
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.7655937671661377
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.7998688817024231
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8057761192321777
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.7989939451217651
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8130081295967102
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8493492603302002
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# x_restored.shape=torch.Size([8, 1, 372, 372])		x_distorted.shape=torch.Size([8, 1, 372, 372])
# Loss: 0.8305684924125671
# 		Step 0/3...
# 		Step 1/3...
# KeyboardInterrupt

# %%
import plotly.express as px
# from nppc.auxil import imgs_to_grid
from IPython.core.display import Markdown

# samples_list = np.random.RandomState(1).randint(0, len(test_set), 10)
t_list = torch.linspace(-3, 3, 21).to(device)


def imgs_to_grid(imgs, nrows=None, **make_grid_args):
    imgs = imgs.detach().cpu()
    if imgs.ndim == 5:
        nrow = imgs.shape[1]
        imgs = imgs.reshape(imgs.shape[0] * imgs.shape[1], imgs.shape[2], imgs.shape[3], imgs.shape[4])
    elif nrows is None:
        nrow = int(np.ceil(imgs.shape[0] ** 0.5))

    make_grid_args2 = dict(value_range=(0, 1), pad_value=1.)
    make_grid_args2.update(make_grid_args)
    img = torchvision.utils.make_grid(imgs, nrow=nrow, **make_grid_args2).clamp(0, 1)
    return img

def scale_img(x):
    return x / torch.abs(x).flatten(-3).max(-1)[0][..., None, None, None] / 1.5 + 0.5

def tensor_img_to_numpy(x):
    return x.detach().permute(-2, -1, -3).cpu().numpy()

def imshow(img, scale=1, **kwargs):
    if isinstance(img, torch.Tensor):
        img = tensor_img_to_numpy(img)
    img = img.clip(0, 1)

    fig = px.imshow(img, **kwargs).update_layout(
        height=img.shape[0] * scale,
        width=img.shape[1] * scale,
        margin=dict(t=0, b=0, l=0, r=0),
        xaxis_showticklabels=False,
        yaxis_showticklabels=False,
    )
    return fig


test_total = 2
test_count = 0
for iter, data in enumerate(train_loader):
    
    # Obtain subsampled k-space, target image, k-space mask respectively
    y_distorted, x_org, mask = data
    x_org = x_org.to(device)
    mask = mask.to(device)
    y_distorted = y_distorted.to(device)
    # Zero-filled image ("distorted" in NPPC terms)
    x_distorted = torch.tensor(abs(ifftc(torch.tensor(fftc(x_org[..., 0] + 1j * x_org[..., 1])) * mask[..., 0]))).to(device).float()[:, None, ...]
        
    with torch.no_grad():
        x_restored = single_MoDL(y_distorted.float()[0][None], mask=mask[0][None])
        x_restored = cplx.abs(x_restored.detach())[:, None, ...]
        w_mat = nppc_net(x_distorted[0][None], x_restored[0][None])
    
    display(Markdown('## Sample \# ...'))
    display(Markdown('### Original, Distorted, Restored:'))
    imshow(imgs_to_grid(torch.stack((cplx.abs(x_org)[0], x_distorted[0], x_restored[0].squeeze()))[None, :, 0]), scale=2).show()
    
    display(Markdown('### Principal directions:'))
    imgs = t_list[:, None, None, None, None] * w_mat + x_restored[0][None][None]
    imgs = torch.cat((scale_img(w_mat), imgs), dim=0)
    imgs = imgs.transpose(0, 1).contiguous()
    imshow(imgs_to_grid(imgs), scale=1.6).show()
    
    if test_count == test_total:
        break
    else:
        test_count += 1
# Out:
# 		Step 0/3...
# 		Step 1/3...
# 		Step 2/3...
# ## Sample \# ...
# ### Original, Distorted, Restored:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 62
#      60 display(Markdown('## Sample \# ...'))
#      61 display(Markdown('### Original, Distorted, Restored:'))
# ---> 62 imshow(imgs_to_grid(torch.stack((cplx.abs(x_org)[0], x_distorted[0], x_restored[0].squeeze()))[None, :, 0]), scale=2).show()
#      64 display(Markdown('### Principal directions:'))
#      65 imgs = t_list[:, None, None, None, None] * w_mat + x_restored[0][None][None]
#
# RuntimeError: stack expects each tensor to be equal size, but got [372, 372] at entry 0 and [1, 372, 372] at entry 1

# %%
import matplotlib.pyplot as plt
# fig, ax = plt.subplots(1, 5)
# for c in range(5):
#     ax[c].imshow(w_mat[0, c, 0], cmap='inferno', origin='lower', vmin=-0.5, vmax=0.5)
# fig.set_size_inches(13, 5)

c = 0
alphas = np.linspace(-0.5, 0.5, 10)
fig, ax = plt.subplots(1, len(alphas))
for i, alpha in enumerate(alphas):
    ax[i].imshow(x_restored[0, 0] + alpha * w_mat[0, c, 0], cmap='inferno', origin='lower', vmin=0, vmax=1.5)
fig.set_size_inches(30, 7)
fig.tight_layout()
fig.savefig('/home/alon_granek/PythonProjects/NPPC/1st pc attempt.png')
# Out:
# <div id='ce040592-553c-48c4-84dd-0c4c8dad1777'></div>

# %%
#todo
#   Make sure NPPCs are data-consistent.
#   Unrolled NPPC net?
#       DC over the whole set (not only \hat{x})

import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2)
ax[0].imshow(x_distorted[0, 0])
ax[1].imshow(x_restored[0, 0])
# Out:
# <div id='d5a9466c-72af-4174-915d-ce667fead2f5'></div>
